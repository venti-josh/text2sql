# %%
from vanna.openai import OpenAI_Chat
from vanna.chromadb import ChromaDB_VectorStore
from vanna.base import VannaBase


class Text2SQL(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, config=config)


CONFIG = {
    "api_key": "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",
    "model": "gpt-4o",
    "path": "../chromadb",
    "client": "persistent",
}

model: VannaBase = Text2SQL(CONFIG)

# %%
from tables import TABLES

# %%
DDL_PATH = "dbo.ddl"

def get_ddl(table):
    with open(DDL_PATH, "r") as f:
        ddl = [line.replace("\n", "") for line in f.readlines()]
        start = 0
        end = 0
        for i, line in enumerate(ddl):
            stripped_line = line.strip()
            if stripped_line.endswith(f"bizfinway_SIT_STG_TechnoPaints.dbo.{table} ("):
                start = i
            if stripped_line.endswith(");") and start != 0:
                end = i + 1
                break
        return "\n".join(ddl[start:end])

# %%
# List of (table, description, usage, ddl)
TABLES_WITH_DDL = [
    (table[0], table[1], table[2], get_ddl(table[0])) for table in TABLES
]

# with open("tables.ddl", "w") as output_file:
#     for table in TABLES_WITH_DDL:
#         output_file.write(table[3]+ "\n\n")

# %%
def add_table_documentation(model: VannaBase, table: tuple[str, str, str, str], include_description=False, include_usage=False, include_ddl=False):
    if include_description:
        model.add_documentation(f"The table {table[0]} is used for {table[1]}")
    if include_usage:
        model.add_documentation(f"To use {table[0]}, you should {table[2]}")
    if include_ddl:
        model.add_ddl(table[3])

# %%
for table in TABLES_WITH_DDL:
    add_table_documentation(
        model, table, include_description=True, include_usage=True, include_ddl=True
    )

# %%
model.ask(
    "What are the delivery timelines for purchase order SK10001477?",
    auto_train=False,
    visualize=False,
)
# Out:
# SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \nCREATE TABLE bizfinway_SIT_STG_TechnoPaints.dbo.SD_DELIVERYTYPE_C (\n\tDELIVERYTYPE_CODE varchar(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,\n\tDESCRIPTION varchar(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,\n\tNORANGE_CODE varchar(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,\n\tPGI_MANDATORY bit NULL,\n\tCANCELATIONDELIVERYTYPE_CODE varchar(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,\n\tPACKING bit NULL,\n\tTRANSPORTATIONPLANNING bit NULL,\n\tDEFAULTSTATUS_CODE bit NULL,\n\tACTIVE bit NOT NULL,\n\tCREATEDBY numeric(4,0) NULL,\n\tCREATEDON datetime NULL,\n\tMODIFIEDBY numeric(4,0) NULL,\n\tMODIFIEDON datetime NULL,\n\tREPLACEMENT_IND bit NULL,\n\tDOCREVERSAL_IND bit NULL,\n\tMOVETYPE_CODE decimal(18,0) NULL,\n\tRETURNPACKAGEREQ_IND bit NULL,\n\tPACKINGBOXDETAILREQUIRED bit NULL,\n\tSERIALCHARACTERISTICS_REQD bit DEFAULT 0 NOT NULL,\n\tDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tLOCALDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tSTOCKTRANSFER_IND bit NULL,\n\tSALESBOM_IND bit NOT NULL,\n\tCONSTRAINT PK_SD_DELIVTYPE_C PRIMARY KEY (DELIVERYTYPE_CODE)\n);\n\nCREATE TABLE bizfinway_SIT_STG_TechnoPaints.dbo.GL_PURCHASEORG_C (\n\tPURORG_CODE numeric(4,0) NOT NULL,\n\tDESCRIPTION varchar(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,\n\tACTIVE bit NOT NULL,\n\tCREATEDBY numeric(4,0) NULL,\n\tCREATEDON datetime NULL,\n\tMODIFIEDBY numeric(4,0) NULL,\n\tMODIFIEDON datetime NULL,\n\tDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tLOCALDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tCONSTRAINT PK_GL_PURCHASEORG_C PRIMARY KEY (PURORG_CODE)\n);\n\nCREATE TABLE bizfinway_SIT_STG_TechnoPaints.dbo.GL_SALESAREA_C (\n\tSALEORG_CODE numeric(4,0) NOT NULL,\n\tDISTCHANNEL_CODE numeric(4,0) NOT NULL,\n\tDIVISION_CODE numeric(4,0) NOT NULL,\n\tACTIVE bit NOT NULL,\n\tCREATEDBY numeric(4,0) NULL,\n\tCREATEDON datetime NULL,\n\tMODIFIEDBY numeric(4,0) NULL,\n\tMODIFIEDON datetime NULL,\n\tDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tLOCALDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tCONSTRAINT PK_GL_SALESAREA_C PRIMARY KEY (SALEORG_CODE,DISTCHANNEL_CODE,DIVISION_CODE)\n);\n\nCREATE TABLE bizfinway_SIT_STG_TechnoPaints.dbo.SD_ORDERCONFIGURATION_C (\n\tDOCTYPE_CODE varchar(6) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,\n\tRETURN_IND bit NULL,\n\tNORANGE_CODE varchar(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,\n\tPRICINGSCHEMA_CODE varchar(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,\n\tSALESAREAWISEPRICING bit NULL,\n\tMATCHARINFO_REQUIRED bit NULL,\n\tPACKAGEINFO_REQUIRED bit NULL,\n\tPONO_REQUIRED bit NULL,\n\tDELIVERYBLOCK bit NULL,\n\tBILLBLOCK bit NULL,\n\tCREDITLIMITCHECK bit NULL,\n\tCREDITLIMIT_HOLDORDER bit NULL,\n\tCOMMITEDDATE_REQUIRED bit NULL,\n\tRELEASE_REQUIRED bit NULL,\n\tMAIL_REQUIRED bit NULL,\n\tLOCAL_IND bit NULL,\n\tEXPORT_IND bit NULL,\n\tJOBWORK_IND bit NULL,\n\tSTOCKTRANSFER_IND bit NULL,\n\tMATRESERVATION_ALLOWED bit NULL,\n\tSTOCKDISPLAY_IND bit NULL,\n\tTRANSPLAN_IND bit NULL,\n\tDEFAULTSTATUS_CODE bit NULL,\n\tCREATEDBY numeric(18,0) NULL,\n\tCREATEDON datetime NULL,\n\tMODIFIEDBY numeric(18,0) NULL,\n\tMODIFIEDON datetime NULL,\n\tACTIVE bit NOT NULL,\n\tPURREQ_IND bit NULL,\n\tALWDFORBLOCKCUSTOMER bit NULL,\n\tHSSLINK_IND bit DEFAULT 0 NULL,\n\tSERVICEBILL_IND bit DEFAULT 0 NOT NULL,\n\tSERIALCHARACTERISTICS_REQD bit DEFAULT 0 NOT NULL,\n\tDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tLOCALDATATRANSFERFLAG char(1) COLLATE SQL_Latin1_General_CP1_CI_AS DEFAULT 'N' NULL,\n\tRecurring_flag bit NULL,\n\ ...
# Using model gpt-4o for 7617.0 tokens (approx)
# LLM Response: The provided context is insufficient to generate the SQL query. The context does not include information about the tables MM_PUR_PO_T or MM_PUR_PO_H, which are necessary to find details related to purchase orders, including delivery timelines.
# The provided context is insufficient to generate the SQL query. The context does not include information about the tables MM_PUR_PO_T or MM_PUR_PO_H, which are necessary to find details related to purchase orders, including delivery timelines.
# If you want to run the SQL query, connect to a database first.
